# %% [markdown]
# # COVID-19 government measures data
#
# This dataset covers the COVID-19 measures taken by the Dutch government

# %%
import requests
import pandas as pd

# %%
start_date = "2020-01-01"
end_date = pd.to_datetime('today').normalize()

date_range = pd.date_range(start=start_date, end=end_date, freq="D")

print(date_range)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-06-11', '2021-06-12', '2021-06-13', '2021-06-14',
#                '2021-06-15', '2021-06-16', '2021-06-17', '2021-06-18',
#                '2021-06-19', '2021-06-20'],
#               dtype='datetime64[ns]', length=537, freq='D')

# %%
base_url = "https://covidtrackerapi.bsg.ox.ac.uk/api/v2/stringency/actions/NLD/"
for date in date_range:
    try:
        df = df.read_parquet(f"../data/covidtracker/{date_str}.parquet")
    except:
        date_str = str(date)[:10]
        response = requests.get(f"{base_url}{date_str}")
        json_data = response.json()
        df = pd.DataFrame(
            {
                "date":[date],
                "data":[json_data]
            }
        )
        df.to_parquet(f"../data/covidtracker/{date_str}.parquet")
        print(f"Collected data for {date_str}")
# Out:
# Collected data for 2020-01-01
# Collected data for 2020-01-02
# Collected data for 2020-01-03
# Collected data for 2020-01-04
# Collected data for 2020-01-05
# Collected data for 2020-01-06
# Collected data for 2020-01-07
# Collected data for 2020-01-08
# Collected data for 2020-01-09
# Collected data for 2020-01-10
# Collected data for 2020-01-11
# Collected data for 2020-01-12
# Collected data for 2020-01-13
# Collected data for 2020-01-14
# Collected data for 2020-01-15
# Collected data for 2020-01-16
# Collected data for 2020-01-17
# Collected data for 2020-01-18
# Collected data for 2020-01-19
# Collected data for 2020-01-20
# Collected data for 2020-01-21
# Collected data for 2020-01-22
# Collected data for 2020-01-23
# Collected data for 2020-01-24
# Collected data for 2020-01-25
# Collected data for 2020-01-26
# Collected data for 2020-01-27
# Collected data for 2020-01-28
# Collected data for 2020-01-29
# Collected data for 2020-01-30
# Collected data for 2020-01-31
# ...
